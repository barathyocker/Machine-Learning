# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent= dataset[[ 'age', 'bmi', 'children', 'sex_male', 'smoker_yes' ]]

# %%
dependent=dataset[['charges' ]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
import pandas as pd

# %%
import numpy as py

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel': ['rbf', 'poly','sigmoid','linear'],
             'C': [2000,3000,4000,5000],'gamma':['auto','scale']}

grid =GridSearchCV(SVR(), param_grid, refit=True, verbose=3 ,n_jobs=-1)

#fitting model for grid
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [2000, 3000, 4000, 5000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("the R_score value for the best parameter {}:".format(grid.best_params_))
# Out:
# the R_score value for the best parameter {'C': 5000, 'gamma': 'auto', 'kernel': 'poly'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.135216      0.035231         0.054636        0.011297    2000
# 1        0.205337      0.030635         0.018481        0.008503    2000
# 2        0.142629      0.018620         0.026178        0.006627    2000
# 3        0.127107      0.017231         0.012676        0.002730    2000
# 4        0.150338      0.014303         0.055774        0.015808    2000
# 5        0.179697      0.026197         0.021398        0.009184    2000
# 6        0.137465      0.019792         0.027876        0.009995    2000
# 7        0.131921      0.026401         0.016211        0.006075    2000
# 8        0.139645      0.023537         0.051958        0.006901    3000
# 9        0.277661      0.090323         0.020805        0.013615    3000
# 10       0.138175      0.019631         0.034933        0.012620    3000
# 11       0.149029      0.037827         0.024928        0.016320    3000
# 12       0.161052      0.037319         0.053612        0.007497    3000
# 13       0.351939      0.165168         0.021453        0.015835    3000
# 14       0.114343      0.023881         0.022473        0.008772    3000
# 15       0.189805      0.039218         0.021112        0.010247    3000
# 16       0.151687      0.034401         0.051098        0.009759    4000
# 17       0.315894      0.145211         0.016115        0.004704    4000
# 18       0.134625      0.032372         0.028798        0.016273    4000
# 19       0.184660      0.056659         0.011908        0.003263    4000
# 20       0.136093      0.034975         0.044787        0.004921    4000
# 21       0.471490      0.258503         0.012611        0.001358    4000
# 22       0.112940      0.021886         0.019805        0.006655    4000
# 23       0.180153      0.054162         0.015711        0.011476    4000
# 24       0.169388      0.027765         0.057258        0.022367    5000
# 25       0.567398      0.289569         0.021443        0.005114    5000
# 26       0.164550      0.036341         0.043336        0.016578    5000
# 27       0.226328      0.029262         0.017205        0.005932    5000
# 28       0.182884      0.041112         0.064114        0.016558    5000
# 29       0.541633      0.260169         0.014999        0.002930    5000
# 30       0.119451      0.010365         0.030008        0.014162    5000
# 31       0.171939      0.022273         0.014241        0.002535    5000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
#
#                                                params  split0_test_score  \
# 0       {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.814076
# 1      {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.845403
# 2   {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.401855
# 3    {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.605277
# 4      {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.814295
# 5     {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.845581
# 6   {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.385658
# 7   {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.605277
# 8       {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.828670
# 9      {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.846775
# 10  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -1.090896
# 11   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.657470
# 12     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.828795
# 13    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.846874
# 14  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...          -1.761871
# 15  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.657470
# 16      {'C': 4000, 'gamma': 'auto', 'kernel': 'rbf'}           0.838516
# 17     {'C': 4000, 'gamma': 'auto', 'kernel': 'poly'}           0.848176
# 18  {'C': 4000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -3.632380
# 19   {'C': 4000, 'gamma': 'auto', 'kernel': 'linear'}           0.660277
# 20     {'C': 4000, 'gamma': 'scale', 'kernel': 'rbf'}           0.838637
# 21    {'C': 4000, 'gamma': 'scale', 'kernel': 'poly'}           0.847935
# 22  {'C': 4000, 'gamma': 'scale', 'kernel': 'sigmo...          -3.534876
# 23  {'C': 4000, 'gamma': 'scale', 'kernel': 'linear'}           0.660277
# 24      {'C': 5000, 'gamma': 'auto', 'kernel': 'rbf'}           0.838987
# 25     {'C': 5000, 'gamma': 'auto', 'kernel': 'poly'}           0.849278
# 26  {'C': 5000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -5.661969
# 27   {'C': 5000, 'gamma': 'auto', 'kernel': 'linear'}           0.660277
# 28     {'C': 5000, 'gamma': 'scale', 'kernel': 'rbf'}           0.839143
# 29    {'C': 5000, 'gamma': 'scale', 'kernel': 'poly'}           0.849180
# 30  {'C': 5000, 'gamma': 'scale', 'kernel': 'sigmo...          -5.587576
# 31  {'C': 5000, 'gamma': 'scale', 'kernel': 'linear'}           0.660277
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.781092           0.794081           0.794075
# 1            0.805639           0.816733           0.805143
# 2           -0.508082          -0.452827          -0.751013
# 3            0.583646           0.697368           0.532547
# 4            0.780971           0.794227           0.793983
# 5            0.805624           0.816612           0.805133
# 6           -0.537098          -0.474912          -0.477335
# 7            0.583646           0.697368           0.532547
# 8            0.790265           0.811049           0.812892
# 9            0.805323           0.817309           0.805191
# 10          -1.761043          -1.734344          -2.304377
# 11           0.583501           0.697875           0.529117
# 12           0.790105           0.811123           0.812857
# 13           0.805331           0.817283           0.805239
# 14          -2.139307          -1.704369          -2.340839
# 15           0.583501           0.697875           0.529117
# 16           0.795897           0.820403           0.815606
# 17           0.804693           0.817598           0.805943
# 18          -3.671594          -3.645964          -4.403307
# 19           0.583489           0.697920           0.529117
# 20           0.795748           0.820474           0.815572
# 21           0.804701           0.817607           0.806030
# 22          -3.710653          -3.355452          -4.463480
# 23           0.583489           0.697920           0.529117
# 24           0.801418           0.824140           0.820352
# 25           0.804530           0.817095           0.804724
# 26          -6.173225          -5.808881          -7.434892
# 27           0.583489           0.697919           0.528640
# 28           0.801308           0.824177           0.820269
# 29           0.804663           0.817089           0.804538
# 30          -6.464665          -5.733393          -7.528981
# 31           0.583489           0.697919           0.528640
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.733656         0.783396        0.027014               16
# 1            0.754961         0.805576        0.029233               10
# 2           -0.111859        -0.445127        0.205197               26
# 3            0.681425         0.620053        0.061555               23
# 4            0.733663         0.783428        0.027068               15
# 5            0.754962         0.805582        0.029272                9
# 6           -0.111187        -0.397238        0.150976               25
# 7            0.681425         0.620053        0.061555               23
# 8            0.741829         0.796941        0.030140               14
# 9            0.758994         0.806718        0.028279                6
# 10          -1.050280        -1.588188        0.469215               27
# 11           0.655785         0.624750        0.060379               21
# 12           0.741835         0.796943        0.030174               13
# 13           0.758988         0.806743        0.028307                5
# 14          -1.048739        -1.799025        0.443311               28
# 15           0.655785         0.624750        0.060379               21
# 16           0.747537         0.803592        0.031138               12
# 17           0.760524         0.807387        0.028190                3
# 18          -2.331430        -3.536935        0.669772               30
# 19           0.655735         0.625308        0.060700               17
# 20           0.747543         0.803595        0.031176               11
# 21           0.760519         0.807358        0.028122                4
# 22          -2.226415        -3.458175        0.722226               29
# 23           0.655735         0.625308        0.060700               17
# 24           0.748310         0.806641        0.031529                8
# 25           0.762302         0.807586        0.027917                1
# 26          -4.099009        -5.835595        1.069424               31
# 27           0.655731         0.625211        0.060851               19
# 28           0.748315         0.806642        0.031559                7
# 29           0.762291         0.807552        0.027892                2
# 30          -4.041185        -5.871160        1.144450               32
# 31           0.655731         0.625211        0.060851               19

# %%
age_input = float(input("age "))
bmi_input = float(input('bmi '))
children_input = float(input("children "))
sex_male_input = input("sex_male 0 or 1 ")
smoker_yes_input = input ("smoker_yes 0 or 1 ")
# Out:
# age 28
# bmi 33
# children 3
# sex_male 0 or 1 1
# smoker_yes 0 or 1 0

# %%
scx=sc.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
scx
# Out:
# array([[-0.75028215,  0.44157533,  1.5507325 ,  0.91412058, -0.51395617]])

# %%
future_prediction=grid.predict(scx)
print("future_predicition={}".format(future_prediction))
# Out:
# future_predicition=[5514.29452285]

# %%
grid_predictions=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

# %%
r_score
# Out:
# 0.8538025544319938
