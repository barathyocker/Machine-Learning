# %%
import pandas as pd
import numpy as py

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent= dataset[[ 'age', 'bmi', 'children', 'sex_male', 'smoker_yes' ]]

# %%
dependent=dataset[['charges' ]]

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
independent= sc.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.tree import DecisionTreeRegressor

param_grid = {'criterion': ['squared_error', 'friedman_mse','absolute_error','poison'],
             'splitter': ['best','random'],'max_features':['auto','sqrt','log2']}

grid =GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3 ,n_jobs=-1)

# %%
#fitting model for grid
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'squared_error', 'absolute_error', 'friedman_mse', 'poisson'}. Got 'poison' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'poisson', 'squared_error', 'absolute_error'}. Got 'poison' instead.
#
# --------------------------------------------------------------------------------
# 12 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'poisson', 'friedman_mse', 'squared_error', 'absolute_error'}. Got 'poison' instead.
#
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'poisson', 'absolute_error', 'squared_error'}. Got 'poison' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.69417767 0.68794445 0.68294325 0.6169735  0.63267323 0.63081239
#  0.70423155 0.65978129 0.68378293 0.64528459 0.64559979 0.62179413
#  0.71082351 0.69865505 0.67221411 0.70594251 0.70085053 0.6937891
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poison'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("the R_score value for the best parameter {}:".format(grid.best_params_))
# Out:
# the R_score value for the best parameter {'criterion': 'absolute_error', 'max_features': 'auto', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.039109      0.006183         0.002818        0.000406
# 1        0.017474      0.006332         0.003288        0.000766
# 2        0.009813      0.006742         0.002022        0.000634
# 3        0.009162      0.008343         0.001903        0.001021
# 4        0.008488      0.007179         0.004581        0.004401
# 5        0.004909      0.000917         0.002058        0.000109
# 6        0.007673      0.001026         0.006595        0.007087
# 7        0.006153      0.000521         0.002312        0.000409
# 8        0.006379      0.001000         0.002535        0.000657
# 9        0.004840      0.000430         0.002003        0.000002
# 10       0.007015      0.000846         0.001998        0.000005
# 11       0.005347      0.001101         0.002306        0.000605
# 12       0.063923      0.009957         0.003310        0.000872
# 13       0.056361      0.009660         0.002957        0.000886
# 14       0.044675      0.004581         0.002634        0.000473
# 15       0.036790      0.012614         0.002260        0.000393
# 16       0.049151      0.009753         0.002803        0.000397
# 17       0.041861      0.010044         0.002698        0.000606
# 18       0.001005      0.000004         0.000000        0.000000
# 19       0.000605      0.000494         0.000000        0.000000
# 20       0.000803      0.000401         0.000000        0.000000
# 21       0.000803      0.000401         0.000000        0.000000
# 22       0.000712      0.000592         0.000000        0.000000
# 23       0.000600      0.000490         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               auto           best
# 7     friedman_mse               auto         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               auto           best
# 13  absolute_error               auto         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18          poison               auto           best
# 19          poison               auto         random
# 20          poison               sqrt           best
# 21          poison               sqrt         random
# 22          poison               log2           best
# 23          poison               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.729540
# 1   {'criterion': 'squared_error', 'max_features':...           0.733801
# 2   {'criterion': 'squared_error', 'max_features':...           0.701797
# 3   {'criterion': 'squared_error', 'max_features':...           0.675946
# 4   {'criterion': 'squared_error', 'max_features':...           0.696465
# 5   {'criterion': 'squared_error', 'max_features':...           0.685990
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.723077
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.624786
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.775796
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.690014
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.749973
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.598562
# 12  {'criterion': 'absolute_error', 'max_features'...           0.742353
# 13  {'criterion': 'absolute_error', 'max_features'...           0.687369
# 14  {'criterion': 'absolute_error', 'max_features'...           0.705931
# 15  {'criterion': 'absolute_error', 'max_features'...           0.730330
# 16  {'criterion': 'absolute_error', 'max_features'...           0.693593
# 17  {'criterion': 'absolute_error', 'max_features'...           0.758263
# 18  {'criterion': 'poison', 'max_features': 'auto'...                NaN
# 19  {'criterion': 'poison', 'max_features': 'auto'...                NaN
# 20  {'criterion': 'poison', 'max_features': 'sqrt'...                NaN
# 21  {'criterion': 'poison', 'max_features': 'sqrt'...                NaN
# 22  {'criterion': 'poison', 'max_features': 'log2'...                NaN
# 23  {'criterion': 'poison', 'max_features': 'log2'...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.619810           0.725011           0.725442
# 1            0.596870           0.697514           0.742832
# 2            0.638714           0.677372           0.720088
# 3            0.608323           0.503448           0.637938
# 4            0.659208           0.376351           0.698891
# 5            0.564759           0.581588           0.679252
# 6            0.653703           0.733644           0.732005
# 7            0.558772           0.711667           0.722102
# 8            0.621890           0.754713           0.680589
# 9            0.560550           0.665291           0.649117
# 10           0.589895           0.565697           0.622388
# 11           0.515333           0.670382           0.666871
# 12           0.601132           0.740989           0.720956
# 13           0.566152           0.759786           0.757422
# 14           0.453931           0.700936           0.752719
# 15           0.660258           0.723545           0.718532
# 16           0.680743           0.687053           0.747005
# 17           0.639982           0.687448           0.667007
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.671085         0.694178        0.042994                6
# 1            0.668705         0.687944        0.052672                8
# 2            0.676745         0.682943        0.027426               10
# 3            0.659212         0.616973        0.061097               18
# 4            0.732451         0.632673        0.130242               15
# 5            0.642472         0.630812        0.049625               16
# 6            0.678728         0.704232        0.032234                3
# 7            0.681580         0.659781        0.060793               12
# 8            0.585927         0.683783        0.073368                9
# 9            0.661451         0.645285        0.044400               14
# 10           0.700046         0.645600        0.069115               13
# 11           0.657823         0.621794        0.059269               17
# 12           0.748688         0.710824        0.055629                1
# 13           0.722545         0.698655        0.071338                5
# 14           0.747553         0.672214        0.111145               11
# 15           0.697047         0.705943        0.025414                2
# 16           0.695858         0.700851        0.023675                4
# 17           0.716244         0.693789        0.040777                7
# 18                NaN              NaN             NaN               19
# 19                NaN              NaN             NaN               19
# 20                NaN              NaN             NaN               19
# 21                NaN              NaN             NaN               19
# 22                NaN              NaN             NaN               19
# 23                NaN              NaN             NaN               19

# %%
age_input = float(input("age "))
bmi_input = float(input('bmi '))
children_input = float(input("children "))
sex_male_input = input("sex_male 0 or 1 ")
smoker_yes_input = input ("smoker_yes 0 or 1 ")
# Out:
# age 28
# bmi 33
# children 3
# sex_male 0 or 1 1
# smoker_yes 0 or 1 0

# %%
scx=sc.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
scx
# Out:
# array([[-0.79795355,  0.38330685,  1.58092576,  0.98959079, -0.5074631 ]])

# %%
future_prediction=grid.predict(scx)
print("future_predicition={}".format(future_prediction))
# Out:
# future_predicition=[4449.462]

# %%
grid_predictions=grid.predict(independent)

from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)

# %%
r_score
# Out:
# 0.998667156135576

# %%
import pickle
filename="finalized_decision.sav"
pickle.dump(grid.best_params_,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_decision.sav",'rb'))
result=loaded_model.predict([[-0.79795355,  0.38330685,  1.58092576,  0.98959079, -0.5074631]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 loaded_model=pickle.load(open("finalized_decision.sav",'rb'))
# ----> 2 result=loaded_model.predict([[-0.79795355,  0.38330685,  1.58092576,  0.98959079, -0.5074631]])
#
# AttributeError: 'dict' object has no attribute 'predict'

# %%
loaded_model
# Out:
# {'criterion': 'absolute_error', 'max_features': 'auto', 'splitter': 'best'}
