# %%
import pandas as pd
import numpy as py
import pickle

# %%
dataset = pd.read_csv('icc 2023 virat runs.csv')

# %%
dataset
# Out:
#    match  balls  four  six  runs
# 0      1    116     6    0    85
# 1      2     56     6    0    55
# 2      3     18     3    0    16
# 3      4     97     6    4   103
# 4      5     95     8    2    95
# 5      6      9     0    0     0
# 6      7     94    11    0    88
# 7      8    121    10    0   101

# %%
dataset.columns
# Out:
# Index(['match', 'balls', 'four', 'six', 'runs'], dtype='object')

# %%
independent= dataset[[ 'balls', 'four', 'six']]

# %%
dependent=dataset[['runs' ]]

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.ensemble import RandomForestRegressor

param_grid = {'criterion': ['squared_error', 'friedman_mse','absolute_error','poison'],
             'max_features':['sqrt','log2'], 'n_estimators' : [10,50,100] }

grid =GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3 ,n_jobs=-1)

# %%
#fitting model for grid
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'squared_error', 'poisson', 'friedman_mse'}. Got 'poison' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'friedman_mse', 'poisson', 'squared_error'}. Got 'poison' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'friedman_mse', 'absolute_error', 'squared_error', 'poisson'}. Got 'poison' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan]
#   warnings.warn(
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:1152: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poison'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("the R_score value for the best parameter {}:".format(grid.best_params_))
# Out:
# the R_score value for the best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 10}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.103207      0.038889         0.030931        0.024524
# 1        0.363310      0.129999         0.100158        0.077261
# 2        0.581482      0.123628         0.056549        0.020603
# 3        0.083287      0.017123         0.033253        0.016076
# 4        0.363998      0.100551         0.052562        0.030413
# 5        0.825908      0.243339         0.051386        0.020288
# 6        0.117435      0.048719         0.026999        0.026097
# 7        0.318661      0.154892         0.028472        0.017538
# 8        0.644293      0.165638         0.067170        0.019165
# 9        0.072605      0.015731         0.022643        0.013441
# 10       0.326471      0.089684         0.038554        0.016716
# 11       0.711067      0.053636         0.059336        0.006695
# 12       0.123253      0.037434         0.009101        0.007306
# 13       0.375132      0.028339         0.021482        0.006543
# 14       0.729773      0.072939         0.074631        0.007184
# 15       0.085358      0.015469         0.012513        0.006673
# 16       0.341560      0.038036         0.040638        0.019136
# 17       0.670865      0.136418         0.053431        0.029902
# 18       0.000000      0.000000         0.000000        0.000000
# 19       0.006623      0.008132         0.000000        0.000000
# 20       0.003351      0.006702         0.000000        0.000000
# 21       0.002521      0.002182         0.000000        0.000000
# 22       0.003131      0.006262         0.000000        0.000000
# 23       0.000000      0.000000         0.000000        0.000000
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                 50
# 2    squared_error               sqrt                100
# 3    squared_error               log2                 10
# 4    squared_error               log2                 50
# 5    squared_error               log2                100
# 6     friedman_mse               sqrt                 10
# 7     friedman_mse               sqrt                 50
# 8     friedman_mse               sqrt                100
# 9     friedman_mse               log2                 10
# 10    friedman_mse               log2                 50
# 11    friedman_mse               log2                100
# 12  absolute_error               sqrt                 10
# 13  absolute_error               sqrt                 50
# 14  absolute_error               sqrt                100
# 15  absolute_error               log2                 10
# 16  absolute_error               log2                 50
# 17  absolute_error               log2                100
# 18          poison               sqrt                 10
# 19          poison               sqrt                 50
# 20          poison               sqrt                100
# 21          poison               log2                 10
# 22          poison               log2                 50
# 23          poison               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.150711
# 1   {'criterion': 'squared_error', 'max_features':...           0.987964
# 2   {'criterion': 'squared_error', 'max_features':...           0.876924
# 3   {'criterion': 'squared_error', 'max_features':...           0.881022
# 4   {'criterion': 'squared_error', 'max_features':...           0.917716
# 5   {'criterion': 'squared_error', 'max_features':...           0.959074
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.964578
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.944576
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.873200
# 9   {'criterion': 'friedman_mse', 'max_features': ...          -0.279156
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.937447
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.975764
# 12  {'criterion': 'absolute_error', 'max_features'...           0.765844
# 13  {'criterion': 'absolute_error', 'max_features'...           0.963559
# 14  {'criterion': 'absolute_error', 'max_features'...           0.989828
# 15  {'criterion': 'absolute_error', 'max_features'...           0.690978
# 16  {'criterion': 'absolute_error', 'max_features'...           0.621118
# 17  {'criterion': 'absolute_error', 'max_features'...           0.881066
# 18  {'criterion': 'poison', 'max_features': 'sqrt'...                NaN
# 19  {'criterion': 'poison', 'max_features': 'sqrt'...                NaN
# 20  {'criterion': 'poison', 'max_features': 'sqrt'...                NaN
# 21  {'criterion': 'poison', 'max_features': 'log2'...                NaN
# 22  {'criterion': 'poison', 'max_features': 'log2'...                NaN
# 23  {'criterion': 'poison', 'max_features': 'log2'...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.925356           0.838730                NaN
# 1            0.907872           0.673193                NaN
# 2            0.898700           0.756042                NaN
# 3            0.897175           0.699676                NaN
# 4            0.880299           0.789200                NaN
# 5            0.933184           0.727329                NaN
# 6            0.942518           0.682870                NaN
# 7            0.917981           0.646101                NaN
# 8            0.933609           0.795792                NaN
# 9            0.876050           0.900753                NaN
# 10           0.946925           0.788851                NaN
# 11           0.932146           0.802092                NaN
# 12           0.938697           0.706571                NaN
# 13           0.905501           0.596432                NaN
# 14           0.927798           0.714199                NaN
# 15           0.874517           0.577915                NaN
# 16           0.937559           0.642452                NaN
# 17           0.924691           0.707061                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN                1
# 1                 NaN              NaN             NaN                1
# 2                 NaN              NaN             NaN                1
# 3                 NaN              NaN             NaN                1
# 4                 NaN              NaN             NaN                1
# 5                 NaN              NaN             NaN                1
# 6                 NaN              NaN             NaN                1
# 7                 NaN              NaN             NaN                1
# 8                 NaN              NaN             NaN                1
# 9                 NaN              NaN             NaN                1
# 10                NaN              NaN             NaN                1
# 11                NaN              NaN             NaN                1
# 12                NaN              NaN             NaN                1
# 13                NaN              NaN             NaN                1
# 14                NaN              NaN             NaN                1
# 15                NaN              NaN             NaN                1
# 16                NaN              NaN             NaN                1
# 17                NaN              NaN             NaN                1
# 18                NaN              NaN             NaN                1
# 19                NaN              NaN             NaN                1
# 20                NaN              NaN             NaN                1
# 21                NaN              NaN             NaN                1
# 22                NaN              NaN             NaN                1
# 23                NaN              NaN             NaN                1

# %%
grid_predictions=grid.predict(independent)

from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)

# %%
r_score
# Out:
# 0.9405114047489174
