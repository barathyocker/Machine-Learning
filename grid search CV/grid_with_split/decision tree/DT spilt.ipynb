# %%
import pandas as pd
import numpy as py
import pickle

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent= dataset[[ 'age', 'bmi', 'children', 'sex_male', 'smoker_yes' ]]

# %%
dependent=dataset[['charges' ]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid = {'criterion': ['squared_error', 'friedman_mse','absolute_error','poison'],
             'splitter': ['best','random'],'max_features':['auto','sqrt','log2']}

grid =GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3 ,n_jobs=-1)
#fitting model for grid
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 30 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'absolute_error', 'squared_error', 'friedman_mse', 'poisson'}. Got 'poison' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'squared_error', 'absolute_error', 'poisson'}. Got 'poison' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'squared_error', 'absolute_error', 'friedman_mse', 'poisson'}. Got 'poison' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.68292335 0.68390962 0.61643577 0.56712943 0.5720187  0.579854
#  0.66757214 0.63891425 0.59542205 0.54131536 0.61521939 0.57867022
#  0.61855413 0.68607166 0.62124947 0.60236513 0.58427011 0.57730995
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poison'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("the R_score value for the best parameter {}:".format(grid.best_params_))
# Out:
# the R_score value for the best parameter {'criterion': 'absolute_error', 'max_features': 'auto', 'splitter': 'random'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.049395      0.017193         0.001004        0.002009
# 1        0.028703      0.012013         0.007169        0.003873
# 2        0.005389      0.004946         0.009957        0.005968
# 3        0.002804      0.005608         0.005335        0.006696
# 4        0.005651      0.005826         0.009942        0.005337
# 5        0.008343      0.005298         0.006869        0.005451
# 6        0.009228      0.006438         0.001854        0.001606
# 7        0.012505      0.011694         0.003529        0.006095
# 8        0.015784      0.012671         0.006261        0.004807
# 9        0.014206      0.010283         0.002333        0.003055
# 10       0.017054      0.013025         0.007082        0.010780
# 11       0.009927      0.010937         0.011064        0.003785
# 12       0.096006      0.029111         0.009406        0.007715
# 13       0.074848      0.020486         0.000000        0.000000
# 14       0.068990      0.011761         0.004957        0.006404
# 15       0.040641      0.014882         0.010124        0.007046
# 16       0.045823      0.023150         0.012919        0.013518
# 17       0.037428      0.023051         0.006709        0.008247
# 18       0.002904      0.005807         0.000000        0.000000
# 19       0.002506      0.005012         0.000000        0.000000
# 20       0.003132      0.006264         0.000000        0.000000
# 21       0.000000      0.000000         0.000000        0.000000
# 22       0.003125      0.006251         0.000000        0.000000
# 23       0.000221      0.000442         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               auto           best
# 7     friedman_mse               auto         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               auto           best
# 13  absolute_error               auto         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18          poison               auto           best
# 19          poison               auto         random
# 20          poison               sqrt           best
# 21          poison               sqrt         random
# 22          poison               log2           best
# 23          poison               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.744289
# 1   {'criterion': 'squared_error', 'max_features':...           0.703622
# 2   {'criterion': 'squared_error', 'max_features':...           0.585918
# 3   {'criterion': 'squared_error', 'max_features':...           0.512045
# 4   {'criterion': 'squared_error', 'max_features':...           0.668028
# 5   {'criterion': 'squared_error', 'max_features':...           0.708441
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.734631
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.640179
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.745258
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.699733
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.690507
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.636263
# 12  {'criterion': 'absolute_error', 'max_features'...           0.731118
# 13  {'criterion': 'absolute_error', 'max_features'...           0.692157
# 14  {'criterion': 'absolute_error', 'max_features'...           0.654520
# 15  {'criterion': 'absolute_error', 'max_features'...           0.582983
# 16  {'criterion': 'absolute_error', 'max_features'...           0.658701
# 17  {'criterion': 'absolute_error', 'max_features'...           0.610491
# 18  {'criterion': 'poison', 'max_features': 'auto'...                NaN
# 19  {'criterion': 'poison', 'max_features': 'auto'...                NaN
# 20  {'criterion': 'poison', 'max_features': 'sqrt'...                NaN
# 21  {'criterion': 'poison', 'max_features': 'sqrt'...                NaN
# 22  {'criterion': 'poison', 'max_features': 'log2'...                NaN
# 23  {'criterion': 'poison', 'max_features': 'log2'...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.571495           0.778323           0.644366
# 1            0.718125           0.693304           0.607264
# 2            0.617360           0.664580           0.584714
# 3            0.556687           0.612171           0.540492
# 4            0.305510           0.702976           0.583539
# 5            0.548212           0.581790           0.513189
# 6            0.551413           0.763036           0.630980
# 7            0.618526           0.641645           0.645452
# 8            0.616382           0.379885           0.646847
# 9            0.568626           0.441336           0.494941
# 10           0.665731           0.569247           0.599022
# 11           0.615484           0.718689           0.528739
# 12           0.589022           0.611104           0.507938
# 13           0.635402           0.730728           0.677036
# 14           0.604998           0.613145           0.629762
# 15           0.623931           0.665753           0.622126
# 16           0.395248           0.611024           0.636761
# 17           0.632511           0.672520           0.607857
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.676145         0.682923        0.073234                3
# 1            0.697234         0.683910        0.039242                2
# 2            0.629607         0.616436        0.029765                8
# 3            0.614252         0.567129        0.040255               17
# 4            0.600041         0.572019        0.140223               16
# 5            0.547638         0.579854        0.067855               13
# 6            0.657801         0.667572        0.075548                4
# 7            0.648770         0.638914        0.010627                5
# 8            0.588738         0.595422        0.120030               11
# 9            0.501941         0.541315        0.088926               18
# 10           0.551589         0.615219        0.054119                9
# 11           0.394176         0.578670        0.110281               14
# 12           0.653588         0.618554        0.073568                7
# 13           0.695036         0.686072        0.030857                1
# 14           0.603822         0.621249        0.019042                6
# 15           0.517033         0.602365        0.050062               10
# 16           0.619617         0.584270        0.095906               12
# 17           0.363172         0.577310        0.109546               15
# 18                NaN              NaN             NaN               19
# 19                NaN              NaN             NaN               19
# 20                NaN              NaN             NaN               19
# 21                NaN              NaN             NaN               19
# 22                NaN              NaN             NaN               19
# 23                NaN              NaN             NaN               19

# %%
age_input = float(input("age "))
bmi_input = float(input('bmi '))
children_input = float(input("children "))
sex_male_input = input("sex_male 0 or 1 ")
smoker_yes_input = input ("smoker_yes 0 or 1 ")
# Out:
# age 28
# bmi 33
# children 3
# sex_male 0 or 1 1
# smoker_yes 0 or 1 0

# %%
sc_x=sc.transform #for saving sc.transform sc_x varible is used
sc_transform_value=sc_x([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# C:\Users\2155586\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
sc_transform_value
# Out:
# array([[-0.75028215,  0.44157533,  1.5507325 ,  0.91412058, -0.51395617]])

# %%
future_prediction=grid.predict(sc_transform_value)
print("future_predicition={}".format(future_prediction))
# Out:
# future_predicition=[5209.57885]

# %%
grid_predictions=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

# %%
r_score
# Out:
# 0.7451951772473935
